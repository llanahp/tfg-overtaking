# %% [markdown]
# <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/98702494-b71c4e80-237a-11eb-87ed-17fcd6b3f066.jpg">
#
# This notebook was written by Ultralytics LLC, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://www.ultralytics.com.

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', major=7, minor=0, total_memory=16130MB, multi_processor_count=80)

# %%
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /home/alumnocc/curso/Perception_layer_curso/yolov5
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.1 _CudaDeviceProperties(name='NVIDIA GeForce RTX 2080 Ti', major=7, minor=5, total_memory=11016MB, multi_processor_count=68)

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases).

# %% [markdown]
# Una imagen de coches y jugar con el IOU y la conf para que vean como aparecen nuevas bbox en imagenes complejas
# Probar diferentes NMS
#
# Probar el device para que vean la rapidez de ejecución en GPU

# %%
# !rm -rf runs/detect/exp
# !python detect.py --weights yolov5l.pt --img 640 --conf 0.25 --iou-thres 0.45 --device 0 --source data/images/
Image(filename='runs/detect/exp/coches.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, img_size=640, iou_thres=0.2, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/', update=False, view_img=False, weights=['yolov5l.pt'])
# YOLOv5 v4.0-69-ga5359f6 torch 1.7.1 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11016.3125MB)
#                                     CUDA:1 (NVIDIA GeForce GTX 1080 Ti, 11178.5MB)
#
# Fusing layers...
# Model Summary: 392 layers, 47025981 parameters, 0 gradients, 115.3 GFLOPS
# image 1/3 /home/alumnocc/curso/Perception_layer_curso/yolov5/data/images/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 1 stop sign, 2 handbags, 2 potted plants, 1 cell phone, Done. (0.014s)
# image 2/3 /home/alumnocc/curso/Perception_layer_curso/yolov5/data/images/coches.jpg: 352x640 8 persons, 18 cars, 2 buss, 11 trucks, Done. (0.013s)
# image 3/3 /home/alumnocc/curso/Perception_layer_curso/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 1 cell phone, Done. (0.013s)
# Results saved to runs/detect/exp
# Done. (0.112s)

# %% [markdown]
# Results are saved to `runs/detect`. A full list of available inference sources:
# <img src="https://user-images.githubusercontent.com/26833433/98274798-2b7a7a80-1f94-11eb-91a4-70c73593e26b.jpg" width="900">
